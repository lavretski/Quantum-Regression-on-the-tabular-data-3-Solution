# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import lightgbm as lgb

import optuna
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
# Load the data
train_data = pd.read_csv('internship_train.csv')
submission_data = pd.read_csv('internship_hidden_test.csv')

# %%
# Split the training data into features and target
X_train_all = train_data.drop('target', axis=1)
y_train_all = train_data['target']

# %%
# Split the test data into features
X_submission = submission_data

# %%
# Scale the data using StandardScaler
scaler = StandardScaler()
X_train_all = scaler.fit_transform(X_train_all)
X_submission = scaler.transform(X_submission)

# %%
# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_all, y_train_all, test_size=0.2, random_state=42)

# %%
# Split the training data into training and tests sets
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
# %%time
# Train and evaluate a Linear Regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_val)
mse_lr = mean_squared_error(y_val, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
print('Linear Regression RMSE on val data:', rmse_lr)
# Out:
# Linear Regression RMSE on val data: 29.018063147758934
# CPU times: user 309 ms, sys: 63.8 ms, total: 372 ms
# Wall time: 153 ms

# %%
# %%time
# Train and evaluate a Random Forest Regressor model
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
y_pred_rfr = rfr.predict(X_val)
mse_rfr = mean_squared_error(y_val, y_pred_rfr)
rmse_rfr = np.sqrt(mse_rfr)
print('Random Forest Regressor RMSE on val data:', rmse_rfr)
# Out:
# Random Forest Regressor RMSE on val data: 0.004382381328900737
# CPU times: user 5min 15s, sys: 582 ms, total: 5min 16s
# Wall time: 5min 16s

# %%
# %%time
# Train and evaluate a Gradient Boosting Regressor model
gb = GradientBoostingRegressor(n_estimators=100, random_state=42)
gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_val)
mse_gb = mean_squared_error(y_val, y_pred_gb)
rmse_gb = np.sqrt(mse_gb)
print('Gradient Boosting Regressor RMSE on val data:', rmse_gb)
# Out:
# Gradient Boosting Regressor RMSE on val data: 0.4172525678617058
# CPU times: user 2min 28s, sys: 20.8 ms, total: 2min 28s
# Wall time: 2min 29s

# %%
# %%time
# Train and evaluate a K-Nearest Neighbors Regression model
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_val)
rmse = np.sqrt(mean_squared_error(y_val, y_pred_knn))
print('KNN RMSE on val data:', rmse)
# Out:
# KNN RMSE on val data: 29.878087628237203
# CPU times: user 28.6 s, sys: 9.95 s, total: 38.5 s
# Wall time: 24 s

# %%
# Convert the data into LightGBM format
train_data = lgb.Dataset(X_train, label=y_train)
val_data = lgb.Dataset(X_val, label=y_val)

# Set the hyperparameters for the LightGBM model
params = {
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

lgbm_model = lgb.train(
    params,
    train_data,
    num_boost_round=1000,
    valid_sets=[val_data],
    early_stopping_rounds=50,
    verbose_eval=100
)

y_pred_lgbm = lgbm_model.predict(X_val, num_iteration=lgbm_model.best_iteration)

rmse_lgbm = np.sqrt(mean_squared_error(y_val, y_pred_lgbm))
print('LightGBM RMSE on val data:', rmse_lgbm)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 0.407449
# [200]	valid_0's rmse: 0.11742
# [300]	valid_0's rmse: 0.0855978
# [400]	valid_0's rmse: 0.0765465
# [500]	valid_0's rmse: 0.0726728
# [600]	valid_0's rmse: 0.0705897
# [700]	valid_0's rmse: 0.069589
# [800]	valid_0's rmse: 0.06782
# [900]	valid_0's rmse: 0.0669251
# [1000]	valid_0's rmse: 0.0662841
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's rmse: 0.0662841
# LightGBM RMSE on val data: 0.06628414576913776

# %% [markdown]
# Найкраще себе показують lightgbm і RandomForestRegressor тому попробую потюнити їх гіперпараметри

# %%
def objective(trial):
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'num_leaves': trial.suggest_int('num_leaves', 25, 35),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.99, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.96, 0.98),
        'bagging_freq': trial.suggest_int('bagging_freq', 2, 5),
        'verbose': -1
    }

    lgbm_model = lgb.train(
        params,
        train_data,
        num_boost_round=1000,
        valid_sets=[val_data],
        early_stopping_rounds=50,
        verbose_eval=False
    )
    y_pred = lgbm_model.predict(X_val, num_iteration=lgbm_model.best_iteration)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    return rmse


# Use Optuna to optimize the hyperparameters
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# Train the LightGBM model on the optimized hyperparameters
params = study.best_params
params['objective'] = 'regression'
params['metric'] = 'rmse'
lgbm_model = lgb.train(
    params,
    train_data,
    num_boost_round=1000,
    valid_sets=[val_data],
    early_stopping_rounds=50,
    verbose_eval=100
)

y_pred_lgbm = lgbm_model.predict(X_test, num_iteration=lgbm_model.best_iteration)
rmse_lgbm = np.sqrt(mean_squared_error(y_test, y_pred_lgbm))
print('Optuna LightGBM RMSE on test data:', rmse_lgbm)
# Out:
# [I 2023-03-08 20:55:57,405] A new study created in memory with name: no-name-d67e9f2d-b677-43cd-a67f-c159f7fdabfe
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:56:23,191] Trial 0 finished with value: 0.01018897925828731 and parameters: {'num_leaves': 25, 'learning_rate': 0.014507911197283497, 'feature_fraction': 0.9949359934577625, 'bagging_fraction': 0.9756681726405361, 'bagging_freq': 2}. Best is trial 0 with value: 0.01018897925828731.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:56:45,083] Trial 1 finished with value: 0.012911385414901794 and parameters: {'num_leaves': 35, 'learning_rate': 0.09811474709987661, 'feature_fraction': 0.9962058601148728, 'bagging_fraction': 0.9709958048160401, 'bagging_freq': 4}. Best is trial 0 with value: 0.01018897925828731.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:57:04,636] Trial 2 finished with value: 0.010512423082444284 and parameters: {'num_leaves': 30, 'learning_rate': 0.05109208522663365, 'feature_fraction': 0.9957457217431407, 'bagging_fraction': 0.9633439427022815, 'bagging_freq': 5}. Best is trial 0 with value: 0.01018897925828731.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:57:32,577] Trial 3 finished with value: 0.016388203254663274 and parameters: {'num_leaves': 32, 'learning_rate': 0.01325866601850197, 'feature_fraction': 0.9904865565788977, 'bagging_fraction': 0.9637453294801587, 'bagging_freq': 5}. Best is trial 0 with value: 0.01018897925828731.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:57:50,509] Trial 4 finished with value: 0.011408122860627104 and parameters: {'num_leaves': 25, 'learning_rate': 0.08401334445397067, 'feature_fraction': 0.996398538261155, 'bagging_fraction': 0.9623161260141788, 'bagging_freq': 5}. Best is trial 0 with value: 0.01018897925828731.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:58:12,461] Trial 5 finished with value: 0.00992158192875661 and parameters: {'num_leaves': 33, 'learning_rate': 0.042651159142380685, 'feature_fraction': 0.9990967878080755, 'bagging_fraction': 0.96284183892316, 'bagging_freq': 3}. Best is trial 5 with value: 0.00992158192875661.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:58:32,787] Trial 6 finished with value: 0.011355248729417674 and parameters: {'num_leaves': 32, 'learning_rate': 0.08538779385274073, 'feature_fraction': 0.9927492784860279, 'bagging_fraction': 0.96761634548785, 'bagging_freq': 5}. Best is trial 5 with value: 0.00992158192875661.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:58:52,550] Trial 7 finished with value: 0.0115215761005978 and parameters: {'num_leaves': 26, 'learning_rate': 0.08610846366783725, 'feature_fraction': 0.999131644040799, 'bagging_fraction': 0.9727347416485576, 'bagging_freq': 2}. Best is trial 5 with value: 0.00992158192875661.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:59:17,762] Trial 8 finished with value: 0.009365412194246877 and parameters: {'num_leaves': 32, 'learning_rate': 0.02164728030134216, 'feature_fraction': 0.9935269976116039, 'bagging_fraction': 0.9644374879322798, 'bagging_freq': 2}. Best is trial 8 with value: 0.009365412194246877.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 20:59:38,487] Trial 9 finished with value: 0.011056610873758373 and parameters: {'num_leaves': 33, 'learning_rate': 0.061883595753205116, 'feature_fraction': 0.9917788138865014, 'bagging_fraction': 0.9668577328007738, 'bagging_freq': 3}. Best is trial 8 with value: 0.009365412194246877.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:00:00,741] Trial 10 finished with value: 0.009842319949213984 and parameters: {'num_leaves': 29, 'learning_rate': 0.030085997256926615, 'feature_fraction': 0.9934810539820463, 'bagging_fraction': 0.9794078767827744, 'bagging_freq': 2}. Best is trial 8 with value: 0.009365412194246877.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:00:24,897] Trial 11 finished with value: 0.009964699422693546 and parameters: {'num_leaves': 29, 'learning_rate': 0.03020001215909415, 'feature_fraction': 0.9938196122498415, 'bagging_fraction': 0.9786834950418861, 'bagging_freq': 2}. Best is trial 8 with value: 0.009365412194246877.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:00:46,395] Trial 12 finished with value: 0.009636972545828825 and parameters: {'num_leaves': 28, 'learning_rate': 0.028090000706743955, 'feature_fraction': 0.9933397301163587, 'bagging_fraction': 0.9750217234845983, 'bagging_freq': 3}. Best is trial 8 with value: 0.009365412194246877.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:01:08,272] Trial 13 finished with value: 0.010048173311554623 and parameters: {'num_leaves': 27, 'learning_rate': 0.028408514030985002, 'feature_fraction': 0.9915406684622109, 'bagging_fraction': 0.9741212788056359, 'bagging_freq': 3}. Best is trial 8 with value: 0.009365412194246877.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:01:34,732] Trial 14 finished with value: 0.021819764474286917 and parameters: {'num_leaves': 28, 'learning_rate': 0.010065495579091824, 'feature_fraction': 0.9900047992936869, 'bagging_fraction': 0.9606557807991668, 'bagging_freq': 4}. Best is trial 8 with value: 0.009365412194246877.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:01:59,364] Trial 15 finished with value: 0.00929956288385228 and parameters: {'num_leaves': 35, 'learning_rate': 0.0253234011414044, 'feature_fraction': 0.9942966524325381, 'bagging_fraction': 0.9692734776855165, 'bagging_freq': 3}. Best is trial 15 with value: 0.00929956288385228.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:02:24,254] Trial 16 finished with value: 0.01030219209572037 and parameters: {'num_leaves': 35, 'learning_rate': 0.04314914505975572, 'feature_fraction': 0.9947619799710162, 'bagging_fraction': 0.9684698222697751, 'bagging_freq': 4}. Best is trial 15 with value: 0.00929956288385228.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:02:49,839] Trial 17 finished with value: 0.00883911286030477 and parameters: {'num_leaves': 34, 'learning_rate': 0.020638081845569485, 'feature_fraction': 0.9973965667811067, 'bagging_fraction': 0.9655623187988835, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:03:17,065] Trial 18 finished with value: 0.008860268649525226 and parameters: {'num_leaves': 34, 'learning_rate': 0.018236471787833608, 'feature_fraction': 0.9974414512059322, 'bagging_fraction': 0.9695865458787002, 'bagging_freq': 3}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:03:45,909] Trial 19 finished with value: 0.008932748082691797 and parameters: {'num_leaves': 34, 'learning_rate': 0.020283712190622492, 'feature_fraction': 0.997506104601257, 'bagging_fraction': 0.9656397572757489, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:04:15,160] Trial 20 finished with value: 0.011670770705901373 and parameters: {'num_leaves': 31, 'learning_rate': 0.010430476661785247, 'feature_fraction': 0.997813068574528, 'bagging_fraction': 0.9710022182743773, 'bagging_freq': 3}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:04:41,180] Trial 21 finished with value: 0.008892459317636778 and parameters: {'num_leaves': 34, 'learning_rate': 0.019909937667740272, 'feature_fraction': 0.9974864434538391, 'bagging_fraction': 0.9657967464478686, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:05:04,580] Trial 22 finished with value: 0.009245994297007724 and parameters: {'num_leaves': 34, 'learning_rate': 0.03547971696005955, 'feature_fraction': 0.9976211475291263, 'bagging_fraction': 0.9662661288578591, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:05:30,864] Trial 23 finished with value: 0.008890019659522389 and parameters: {'num_leaves': 34, 'learning_rate': 0.019697458883659483, 'feature_fraction': 0.9982277622745875, 'bagging_fraction': 0.965454472020353, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:05:55,912] Trial 24 finished with value: 0.009396086234644248 and parameters: {'num_leaves': 33, 'learning_rate': 0.020209635177264963, 'feature_fraction': 0.999858761948413, 'bagging_fraction': 0.9687316778686059, 'bagging_freq': 3}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:06:22,312] Trial 25 finished with value: 0.009339415213533707 and parameters: {'num_leaves': 31, 'learning_rate': 0.016856214698118238, 'feature_fraction': 0.9984539132082382, 'bagging_fraction': 0.967250551087616, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:06:44,613] Trial 26 finished with value: 0.009584405489633248 and parameters: {'num_leaves': 34, 'learning_rate': 0.03541514829103905, 'feature_fraction': 0.9966939494551219, 'bagging_fraction': 0.9695094906054998, 'bagging_freq': 4}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:07:11,133] Trial 27 finished with value: 0.009172741640705905 and parameters: {'num_leaves': 33, 'learning_rate': 0.01662420483724443, 'feature_fraction': 0.9956443110740594, 'bagging_fraction': 0.9649024031214357, 'bagging_freq': 3}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:07:35,927] Trial 28 finished with value: 0.008980012099416984 and parameters: {'num_leaves': 35, 'learning_rate': 0.023216233749003057, 'feature_fraction': 0.996975034820236, 'bagging_fraction': 0.9675033826079535, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:08:02,890] Trial 29 finished with value: 0.009581995484536327 and parameters: {'num_leaves': 31, 'learning_rate': 0.014467660720217448, 'feature_fraction': 0.9983258527036439, 'bagging_fraction': 0.9651543588307906, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:08:34,241] Trial 30 finished with value: 0.01018010953069275 and parameters: {'num_leaves': 34, 'learning_rate': 0.010756240680923802, 'feature_fraction': 0.9952833721212785, 'bagging_fraction': 0.970355976329712, 'bagging_freq': 2}. Best is trial 17 with value: 0.00883911286030477.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:09:01,345] Trial 31 finished with value: 0.008816906375776973 and parameters: {'num_leaves': 34, 'learning_rate': 0.019069375651350598, 'feature_fraction': 0.9971228787877501, 'bagging_fraction': 0.9659622788989182, 'bagging_freq': 2}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:09:28,596] Trial 32 finished with value: 0.008917408560146904 and parameters: {'num_leaves': 35, 'learning_rate': 0.017017931662991915, 'feature_fraction': 0.9970704255442804, 'bagging_fraction': 0.966466598876904, 'bagging_freq': 2}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:09:52,766] Trial 33 finished with value: 0.009264083400067262 and parameters: {'num_leaves': 33, 'learning_rate': 0.024210912567445998, 'feature_fraction': 0.996129822756103, 'bagging_fraction': 0.9642981272032554, 'bagging_freq': 2}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:10:14,742] Trial 34 finished with value: 0.009904117105773005 and parameters: {'num_leaves': 32, 'learning_rate': 0.033920655720039654, 'feature_fraction': 0.9965437706564446, 'bagging_fraction': 0.9682242079004908, 'bagging_freq': 3}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:10:40,258] Trial 35 finished with value: 0.008837962285792521 and parameters: {'num_leaves': 34, 'learning_rate': 0.015544092240347899, 'feature_fraction': 0.9959673121961785, 'bagging_fraction': 0.96341827076352, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:11:07,206] Trial 36 finished with value: 0.008844153626843305 and parameters: {'num_leaves': 35, 'learning_rate': 0.014955614023930154, 'feature_fraction': 0.9958006280410164, 'bagging_fraction': 0.9624989270246744, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:11:34,815] Trial 37 finished with value: 0.009066636810870471 and parameters: {'num_leaves': 35, 'learning_rate': 0.014841117045636832, 'feature_fraction': 0.9961689318919853, 'bagging_fraction': 0.9631296774810788, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:12:03,040] Trial 38 finished with value: 0.009200738447422861 and parameters: {'num_leaves': 35, 'learning_rate': 0.012816612375989404, 'feature_fraction': 0.9956914646431781, 'bagging_fraction': 0.9628299900435031, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:12:29,950] Trial 39 finished with value: 0.009187834636891384 and parameters: {'num_leaves': 33, 'learning_rate': 0.014365936363405848, 'feature_fraction': 0.9953262157454048, 'bagging_fraction': 0.9615057288764572, 'bagging_freq': 5}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:12:52,474] Trial 40 finished with value: 0.009437955314924149 and parameters: {'num_leaves': 32, 'learning_rate': 0.024960880388961822, 'feature_fraction': 0.996179007727916, 'bagging_fraction': 0.9638767811686993, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:13:17,173] Trial 41 finished with value: 0.00912309637980461 and parameters: {'num_leaves': 34, 'learning_rate': 0.017430248377364774, 'feature_fraction': 0.9969273895351886, 'bagging_fraction': 0.9620755525558701, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:13:41,774] Trial 42 finished with value: 0.00890649810186323 and parameters: {'num_leaves': 34, 'learning_rate': 0.02224851260437425, 'feature_fraction': 0.9965190760900208, 'bagging_fraction': 0.9600083328526063, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:14:11,192] Trial 43 finished with value: 0.010622245878259794 and parameters: {'num_leaves': 35, 'learning_rate': 0.010266858552938412, 'feature_fraction': 0.9972477947867555, 'bagging_fraction': 0.9635568635523037, 'bagging_freq': 5}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:14:34,119] Trial 44 finished with value: 0.009402878773548435 and parameters: {'num_leaves': 33, 'learning_rate': 0.026082626964525617, 'feature_fraction': 0.995848657359483, 'bagging_fraction': 0.9645958260805747, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:14:53,029] Trial 45 finished with value: 0.009890314554548002 and parameters: {'num_leaves': 25, 'learning_rate': 0.03010227543145716, 'feature_fraction': 0.99685828814158, 'bagging_fraction': 0.9624178581580597, 'bagging_freq': 3}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:15:17,766] Trial 46 finished with value: 0.009235807193708109 and parameters: {'num_leaves': 32, 'learning_rate': 0.01759054858781838, 'feature_fraction': 0.9947581054187767, 'bagging_fraction': 0.9637794401099828, 'bagging_freq': 5}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# ...
# [I 2023-03-08 21:31:43,772] Trial 85 finished with value: 0.009057563474704633 and parameters: {'num_leaves': 34, 'learning_rate': 0.015432549847675812, 'feature_fraction': 0.996912483691684, 'bagging_fraction': 0.9631445805095483, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:32:06,321] Trial 86 finished with value: 0.009575207035414243 and parameters: {'num_leaves': 32, 'learning_rate': 0.026541132924651427, 'feature_fraction': 0.9975100832106277, 'bagging_fraction': 0.9654252957984386, 'bagging_freq': 4}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:32:29,001] Trial 87 finished with value: 0.0092083260449041 and parameters: {'num_leaves': 34, 'learning_rate': 0.024041528741253537, 'feature_fraction': 0.9978550792953307, 'bagging_fraction': 0.966433658406125, 'bagging_freq': 5}. Best is trial 31 with value: 0.008816906375776973.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:32:54,611] Trial 88 finished with value: 0.008771711262656292 and parameters: {'num_leaves': 35, 'learning_rate': 0.018190499553679358, 'feature_fraction': 0.9972740350631916, 'bagging_fraction': 0.9635413072124092, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:33:22,501] Trial 89 finished with value: 0.008888564943025142 and parameters: {'num_leaves': 35, 'learning_rate': 0.013656726177714497, 'feature_fraction': 0.9965825622085761, 'bagging_fraction': 0.9634715036129539, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:33:50,744] Trial 90 finished with value: 0.009185897296562096 and parameters: {'num_leaves': 35, 'learning_rate': 0.01301499773636582, 'feature_fraction': 0.9965857173524963, 'bagging_fraction': 0.9619729480813995, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:34:17,452] Trial 91 finished with value: 0.00884970621047163 and parameters: {'num_leaves': 35, 'learning_rate': 0.017292763963784256, 'feature_fraction': 0.9963649368749155, 'bagging_fraction': 0.9637119889507875, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:34:43,510] Trial 92 finished with value: 0.008967519120280034 and parameters: {'num_leaves': 35, 'learning_rate': 0.01715682838899223, 'feature_fraction': 0.996292218004526, 'bagging_fraction': 0.9635582255668037, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:35:11,103] Trial 93 finished with value: 0.00893920505260672 and parameters: {'num_leaves': 35, 'learning_rate': 0.014363394729184414, 'feature_fraction': 0.9959519548195817, 'bagging_fraction': 0.9626758089677853, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:35:38,920] Trial 94 finished with value: 0.009432475116178434 and parameters: {'num_leaves': 35, 'learning_rate': 0.012282755861116334, 'feature_fraction': 0.9967058116704746, 'bagging_fraction': 0.963941955185042, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:36:04,545] Trial 95 finished with value: 0.008918051495661323 and parameters: {'num_leaves': 35, 'learning_rate': 0.018356948761778125, 'feature_fraction': 0.9971487508000265, 'bagging_fraction': 0.963344975231101, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:36:29,150] Trial 96 finished with value: 0.009167245519958752 and parameters: {'num_leaves': 35, 'learning_rate': 0.02236449841911027, 'feature_fraction': 0.9969344597627607, 'bagging_fraction': 0.9622200099562925, 'bagging_freq': 4}. Best is trial 88 with value: 0.008771711262656292.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:36:53,787] Trial 97 finished with value: 0.008763135819931758 and parameters: {'num_leaves': 35, 'learning_rate': 0.020708123485420414, 'feature_fraction': 0.996377624176011, 'bagging_fraction': 0.9628351517377693, 'bagging_freq': 4}. Best is trial 97 with value: 0.008763135819931758.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:37:18,473] Trial 98 finished with value: 0.009034896996086415 and parameters: {'num_leaves': 34, 'learning_rate': 0.020456753039565272, 'feature_fraction': 0.9954684009178062, 'bagging_fraction': 0.9614112896876262, 'bagging_freq': 4}. Best is trial 97 with value: 0.008763135819931758.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-03-08 21:37:41,059] Trial 99 finished with value: 0.00932404107226177 and parameters: {'num_leaves': 35, 'learning_rate': 0.025640405173499012, 'feature_fraction': 0.9958046889294038, 'bagging_fraction': 0.9628399720576071, 'bagging_freq': 4}. Best is trial 97 with value: 0.008763135819931758.
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028274 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 13192
# [LightGBM] [Info] Number of data points in the train set: 64800, number of used features: 53
# [LightGBM] [Info] Start training from score 50.124621
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 3.61838
# [200]	valid_0's rmse: 0.472682
# [300]	valid_0's rmse: 0.0705863
# [400]	valid_0's rmse: 0.0168694
# [500]	valid_0's rmse: 0.0108087
# [600]	valid_0's rmse: 0.00957062
# [700]	valid_0's rmse: 0.00907328
# [800]	valid_0's rmse: 0.00892683
# [900]	valid_0's rmse: 0.00881567
# [1000]	valid_0's rmse: 0.00876344
# Did not meet early stopping. Best iteration is:
# [996]	valid_0's rmse: 0.00876314
# Optuna LightGBM RMSE on test data: 0.008847919409873142

# %%
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 90, 110),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 4),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 2),
        'random_state': 42,
        'n_jobs': -1
    }

    rfr_model = RandomForestRegressor(**params)
    rfr_model.fit(X_train, y_train)
    y_pred = rfr_model.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    return rmse

# Use Optuna to optimize the hyperparameters
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)

# Train the Random Forest Regressor model on the optimized hyperparameters
params = study.best_params
params['random_state'] = 42
params['n_jobs'] = -1
rfr_model = RandomForestRegressor(**params)
rfr_model.fit(X_train, y_train)

# Make predictions on the validation set
y_pred_rfr = rfr_model.predict(X_test)

# Calculate the RMSE on the validation set
rmse_rfr = np.mean(mean_squared_error(y_test, y_pred_rfr))
print('Optuna Random Forest Regressor RMSE on test data:', rmse_rfr)
# Out:
# [I 2023-03-08 21:38:05,357] A new study created in memory with name: no-name-95fc0e49-c3aa-410a-8b7e-51cec1cddfde
# [I 2023-03-08 21:42:47,448] Trial 0 finished with value: 0.004377300606527633 and parameters: {'n_estimators': 90, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.004377300606527633.
# [I 2023-03-08 21:47:59,423] Trial 1 finished with value: 0.004377071416344892 and parameters: {'n_estimators': 101, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.004377071416344892.
# [I 2023-03-08 21:52:45,225] Trial 2 finished with value: 0.004334586591159707 and parameters: {'n_estimators': 95, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.004334586591159707.
# [I 2023-03-08 21:58:05,263] Trial 3 finished with value: 0.004313231846170207 and parameters: {'n_estimators': 106, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.004313231846170207.
# [I 2023-03-08 22:02:56,811] Trial 4 finished with value: 0.004391077512922175 and parameters: {'n_estimators': 95, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.004313231846170207.
# [I 2023-03-08 22:08:05,096] Trial 5 finished with value: 0.004379472506652008 and parameters: {'n_estimators': 100, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.004313231846170207.
# [I 2023-03-08 22:12:35,767] Trial 6 finished with value: 0.004338607588830054 and parameters: {'n_estimators': 91, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.004313231846170207.
# [I 2023-03-08 22:17:08,390] Trial 7 finished with value: 0.00433715587342619 and parameters: {'n_estimators': 92, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.004313231846170207.
# [I 2023-03-08 22:22:33,552] Trial 8 finished with value: 0.0043635905435242235 and parameters: {'n_estimators': 108, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.004313231846170207.
# [I 2023-03-08 22:27:55,897] Trial 9 finished with value: 0.004311900269342703 and parameters: {'n_estimators': 109, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 9 with value: 0.004311900269342703.
# Optuna Random Forest Regressor RMSE on test data: 1.7666407172451666e-05

# %% [markdown]
# Отже всіх переміг RandomForestRegressor, натреную його на всіх даних із гіперпараметрами з optuna
# і зроблю предсказання на сабмішин дані(тобто на дані для яких немає target), я тут ввів поняття сабмішин
# дані бо використовую після підбору гіперпараметрів на валідації окремо сформовану тестову вибірку щоб уникнути
# перенавчання на валідації

# %%
rfr_final = RandomForestRegressor(**params)
rfr_final.fit(X_train_all, y_train_all)
y_pred_final = rfr.predict(X_submission)

# %%
pd.Series(y_pred_final).to_csv('submission.csv', index = False, header=False)
